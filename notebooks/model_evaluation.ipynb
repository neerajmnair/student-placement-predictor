# %% [markdown]
# # Model Evaluation
#
# The objective of this phase is to evaluate the predictive performance of the best-performing machine learning model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler
)

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
import sys
sys.path.append("..")
from src.preprocess import preprocess_data
(Xtrain,
 Xtest,
 ytrain,
 ytest,
 Xtrain_scaled,
 Xtest_scaled)=preprocess_data("../data/raw/placement.csv")

from src.train import train_models

results = train_models(
    X_train,
    X_test,
    y_train,
    y_test,
    X_train_scaled,
    X_test_scaled
)

# %%
from src.evaluate import evaluate_model
# Out:
# [[954 218]
#  [193 635]]

# %%
plt.figure(figsize=(6,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print(classification_report(
    ytest,
    lr_pred
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1172
#            1       0.74      0.77      0.76       828
#
#     accuracy                           0.79      2000
#    macro avg       0.79      0.79      0.79      2000
# weighted avg       0.80      0.79      0.79      2000

# %% [markdown]
# The classification report indicates balanced predictive performance across both placed and non-placed classes, with strong precision and recall values. This suggests that the model effectively generalizes student placement outcomes based on academic and skill-related features.
